# %%
import pandas as pd
import re
import numpy as np
org_df=pd.read_csv("suicide-blasts-dataset (1).csv")

df=org_df.copy(deep=True)

# %%
pd.set_option("display.max_columns",None)
df.set_index("S#",inplace=True)
df
# Out:
#                           Date  Year                   Islamic Date  \
# S#
# 1      Sunday-November 19-1995  1995  25 Jumaada al-THaany 1416 A.H
# 2       Monday-November 6-2000  2000           10 SHa`baan 1421 A.H
# 3         Wednesday-May 8-2002  2002              25 safar 1423 A.H
# 4          Friday-June 14-2002  2002     3 Raby` al-THaany 1423 A.H
# 5           Friday-July 4-2003  2003     4 Jumaada al-awal 1424 A.H
# ..                         ...   ...                            ...
# 492   Thursday-October-05-2017  2017           13 MuHarram 1439 A.H
# 493   Thursday-October-19-2017  2017           27 MuHarram 1439 A.H
# 494   Thursday-November-9-2017  2017              19 Safar 1439 A.H
# 495    Friday-November-24-2017  2017       5 Rabi Al-Awwal 1439 A.H
# 496  Saturday-November-25-2017  2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# S#
# 1          Holiday      Weekend          NaN  Islamabad  33.718000    73.0718
# 2      Working Day          NaN          NaN    Karachi  24.991800    66.9911
# 3      Working Day          NaN      7:45 AM    Karachi  24.991800    66.9911
# 4      Working Day          NaN  11:10:00 AM    Karachi  24.991800    66.9911
# 5      Working Day          NaN          NaN     Quetta  30.209500    67.0182
# ..             ...          ...          ...        ...        ...        ...
# 492    Working Day          NaN          NaN     Quetta  28.571051  67.496895
# 493    Working Day          NaN      8:00 AM     Quetta        NaN        NaN
# 494    Working Day          NaN      7:00 AM     Quetta  30.221057  67.002524
# 495    Working Day          NaN      7:00 AM   Peshawar  33.970623   71.43862
# 496    Working Day          NaN      7:00 AM     Quetta  30.139626  66.981476
#
#         Province                                           Location  \
# S#
# 1        Capital                                   Egyptian Embassy
# 2          Sindh                              office of Nawa-e-Waqt
# 3          Sindh  Pakistan Navy bus Parked outside Five Star She...
# 4          Sindh                     US Consulate Civil Lines Area
# 5    Balochistan                     Imambargah MeCongy Road Quetta
# ..           ...                                                ...
# 492  Balochistan             Fateh Pur Shrine in Jhal Magsi village
# 493  Balochistan                                   Sariab Mill area
# 494  Balochistan     Quetta's Chaman Housing Scheme on airport road
# 495          KPK            Near Zarghuni Masjid, Phase-2 Hayatabad
# 496  Balochistan                     Sariab Road, near Bus terminal
#
#     Location Category Location Sensitivity Open/Closed Space  \
# S#
# 1             Foreign                 High            Closed
# 2     Office Building                  Low            Closed
# 3               Hotel               Medium            Closed
# 4             Foreign                 High            Closed
# 5           Religious               Medium            Closed
# ..                ...                  ...               ...
# 492         Religious                 High       Open/Closed
# 493           Highway                  Low              Open
# 494    Police_Rangers                  Low              Open
# 495    Police_Rangers                  Low              Open
# 496          Military               Medium              Open
#
#                                Influencing Event/Event     Target Type  \
# S#
# 1                                                  NaN       Foreigner
# 2                                                  NaN           Media
# 3                                                  NaN       Foreigner
# 4                                                  NaN       Foreigner
# 5                                 during Friday prayer       Religious
# ..                                                 ...             ...
# 492                          at the entrance of shrine        Civilian
# 493  explosives-laden vehicle rammed into a securit...  Police_Rangers
# 494                         AIG Hamid Shakil’s vehicle  Police_Rangers
# 495     a Police & Rangers vehicle of AIG Asharf Noor   Police_Rangers
# 496  transport for a colonel in Pakistan's armed fo...        Military
#
#     Targeted Sect if any  Killed Min  Killed Max  Injured Min Injured Max  \
# S#
# 1                    NaN        14.0        15.0          NaN          60
# 2                    NaN         NaN         3.0          NaN           3
# 3              Christian        13.0        15.0         20.0          40
# 4              Christian         NaN        12.0          NaN          51
# 5                 Shiite        44.0        47.0          NaN          65
# ..                   ...         ...         ...          ...         ...
# 492                  NaN        21.0        22.0         25.0         NaN
# 493                  NaN         7.0         7.0         22.0          22
# 494                  NaN         2.0         2.0          8.0           8
# 495                  NaN         1.0         3.0          6.0           8
# 496                  NaN         4.0         4.0         16.0          22
#
#      No. of Suicide Blasts Explosive Weight (max)  \
# S#
# 1                      2.0                    NaN
# 2                      1.0                    NaN
# 3                      1.0                 2.5 Kg
# 4                      1.0                    NaN
# 5                      1.0                    NaN
# ..                     ...                    ...
# 492                    1.0                    NaN
# 493                    1.0                    NaN
# 494                    1.0                   15KG
# 495                    1.0                   20KG
# 496                    1.0                   10KG
#
#                                         Hospital Names  Temperature(C)  \
# S#
# 1                                                  NaN          15.835
# 2                                                  NaN          23.770
# 3    1.Jinnah Postgraduate Medical Center 2. Civil ...          31.460
# 4                                                  NaN          31.430
# 5    1.CMH Quetta\n2.Civil Hospital 3. Boland Medic...          33.120
# ..                                                 ...             ...
# 492  Larkana Hospital, Gandawah District Headquarte...          27.800
# 493                                                NaN          26.000
# 494  Combined Military Hospital (CMH)-(Quetta), Civ...          25.000
# 495                Hayatabad Medical Complex(Peshawar)          22.000
# 496                             Civil Hospital(Quetta)          29.000
#
#      Temperature(F)
# S#
# 1            60.503
# 2            74.786
# 3            88.628
# 4            88.574
# 5            91.616
# ..              ...
# 492          81.000
# 493          79.000
# 494          77.000
# 495          72.000
# 496          84.000
#
# [496 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 496 entries, 1 to 496
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     496 non-null    object
#  1   Year                     496 non-null    int64
#  2   Islamic Date             342 non-null    object
#  3   Blast Day Type           486 non-null    object
#  4   Holiday Type             72 non-null     object
#  5   Time                     285 non-null    object
#  6   City                     496 non-null    object
#  7   Latitude                 493 non-null    float64
#  8   Longitude                493 non-null    object
#  9   Province                 496 non-null    object
#  10  Location                 493 non-null    object
#  11  Location Category        460 non-null    object
#  12  Location Sensitivity     460 non-null    object
#  13  Open/Closed Space        461 non-null    object
#  14  Influencing Event/Event  191 non-null    object
#  15  Target Type              470 non-null    object
#  16  Targeted Sect if any     97 non-null     object
#  17  Killed Min               350 non-null    float64
#  18  Killed Max               480 non-null    float64
#  19  Injured Min              365 non-null    float64
#  20  Injured Max              464 non-null    object
#  21  No. of Suicide Blasts    414 non-null    float64
#  22  Explosive Weight (max)   172 non-null    object
#  23  Hospital Names           297 non-null    object
#  24  Temperature(C)           491 non-null    float64
#  25  Temperature(F)           489 non-null    float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 104.6+ KB

# %%
df.shape
# Out:
# (496, 26)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Year, Islamic Date, Blast Day Type, Holiday Type, Time, City, Latitude, Longitude, Province, Location, Location Category, Location Sensitivity, Open/Closed Space, Influencing Event/Event, Target Type, Targeted Sect if any, Killed Min, Killed Max, Injured Min, Injured Max, No. of Suicide Blasts, Explosive Weight (max), Hospital Names, Temperature(C), Temperature(F)]
# Index: []

# %% [markdown]
# # Short Summary of Data Set

# %% [markdown]
# The "Suicide Bomb Blast Dataset" contains detailed records of 496 suicide bombings in Pakistan spanning from 1995 to 2017. It includes 26 columns covering  contextual information about each incident. Key variables include date, year, Islamic date, city, province, location details, target type, number of blasts, casualties (killed and injured), explosive weight, hospital information, and weather conditions at the time of the blast. The dataset also highlights socio-religious dimensions such as holidays, targeted sects, and influencing events. With both quantitative (casualty counts, temperature, coordinates) and qualitative (target type, location sensitivity, open/closed space) features, this dataset provides a comprehensive foundation for analyzing patterns, trends, and impacts of suicide bombings in Pakistan.

# %% [markdown]
# # Columns Description

# %% [markdown]
# Date – The exact calendar date when the bomb blast occurred.
#
# Year – The year of the incident.
#
# Islamic Date – The corresponding date in the Islamic (Hijri) calendar.
#
# Blast Day Type – The day of the week (e.g., Friday, Monday) or special type of day.
#
# Holiday Type – Whether the blast happened on a public, religious, or national holiday.
#
# Time – The time of day when the explosion occurred.
#
# City – The city in Pakistan where the blast took place.
#
# Latitude – Geographic latitude coordinate of the blast location.
#
# Longitude – Geographic longitude coordinate of the blast location.
#
# Province – Province of Pakistan where the incident occurred.
#
# Location – Specific area or landmark of the blast (e.g., market, mosque).
#
# Location Category – Type of location (e.g., urban, rural, commercial area).
#
# Location Sensitivity – Security sensitivity of the location (e.g., high-profile, public).
#
# Open/Closed Space – Whether the blast occurred in an open or enclosed environment.
#
# Influencing Event/Event – Related event or trigger influencing the attack (e.g., political rally, protest).
#
# Target Type – The main target (e.g., civilians, security forces, religious sites).
#
# Targeted Sect if any – If applicable, the religious sect specifically targeted (e.g., Shia, Sunni).
#
# Killed Min – Minimum number of people killed in the blast.
#
# Killed Max – Maximum number of people killed in the blast.
#
# Injured Min – Minimum number of people injured.
#
# Injured Max – Maximum number of people injured.
#
# No. of Suicide Blasts – Number of suicide bombers involved in the incident.
#
# Explosive Weight (max) – Estimated maximum weight of explosives used.
#
# Hospital Names – Hospitals where victims were taken.
#
# Temperature (C) – Temperature in Celsius on the day of the blast.
#
# Temperature (F) – Temperature in Fahrenheit on the day of the blast.

# %% [markdown]
# # 1) Issues with the dataset

# %% [markdown]
# 1. `Dirty Data`
#
# Table – Suicide_Bomb_Blasts
#
# Date → not in datetime format, inconsistent sequence (validity, consistency)
#
# Islamic Date → many null values (completion)
#
# Blast Day Type → some missing values, not stored as category (completion, validity)
#
# Time → many missing values, mix of text (“Evening”) and exact times (“1:30:00 PM”), inconsistent format (completion, consistency)
#
# Latitude → few missing values (completion)
#
# Longitude → some missing values, stored as object instead of numeric (completion, validity)
#
# Province → case inconsistency e.g., FATA vs. fata (consistency)
#
# Location → 3 rows missing, inconsistent text entries (completion, consistency)
#
# Location Category → missing values, case inconsistency, duplicate categories under different names, not categorical type (completion, consistency, validity)
#
# Location Sensitivity → missing values, case inconsistency, not categorical type (completion, consistency, validity)
#
# Open/Closed Space → missing values, case inconsistency, not categorical type (completion, consistency, validity)
#
# Influencing Event/Event → majority missing (completion)
#
# Target Type → inconsistent case, duplicate categories under different names, not categorical type (consistency, validity)
#
# Targeted Sect if any → mostly missing, case inconsistency, not categorical type (completion, consistency, validity)
#
# Killed Min / Killed Max / Injured Min → some missing, stored as float though should be integer (completion, validity)
#
# Injured Max → missing values, stored as object instead of numeric (completion, validity)
#
# No. of Suicide Blasts → some missing, stored as float instead of integer (completion, validity)
#
# Explosive Weight (max) → majority missing, string manipulation needed, inconsistent format (completion, consistency, validity)
#
# Hospital Names → majority missing, duplicate hospital names, inconsistent spelling (completion, consistency)
#
# 2. `Messy Data`
#
# Table – Suicide_Bomb_Blasts
#
# Time column mixes categorical labels (Morning, Evening) with exact times (tidiness)
#
# Explosive Weight (max) column contains text + numbers instead of a clean numeric field (tidiness)
#
# Hospital Names column stores multiple hospitals in one cell and duplicates (tidiness)
#
# Killed Min / Killed Max / Injured Min / Injured Max could be restructured into a single “Killed (Range)” and “Injured (Range)” column (tidiness)

# %% [markdown]
# # Date

# %%
# code
df["Date"]=df["Date"].str.findall(r"[a-zA-Z]*[,/\-\s]\d{1,2}[,/\-\s]\d{4}").str[0]
df["Date"]=pd.to_datetime(df["Date"],format="mixed")
df["month_name"]=df["Date"].dt.month_name().astype("category")
df["day_name"]=df["Date"].dt.day_name().astype("category")

# %%
# test
df["Date"]
# Out:
# S#
# 1     1995-11-19
# 2     2000-11-06
# 3     2002-05-08
# 4     2002-06-14
# 5     2003-07-04
#          ...
# 492   2017-10-05
# 493   2017-10-19
# 494   2017-11-09
# 495   2017-11-24
# 496   2017-11-25
# Name: Date, Length: 496, dtype: datetime64[ns]

# %% [markdown]
# # Blast Day Type /Holiday Type

# %%
# code
df["Blast Day Type"]=df["Blast Day Type"].astype("category")
df["Holiday Type"]=df["Holiday Type"].str.lower().replace({"eid ul azha holiday":"eid-ul-azha","christmas/ birthday of quaid-e-azam":"christmas/birthday of quaid-e-azam"})
df["Holiday Type"]=df["Holiday Type"].astype("category")

# %%
# test
df["Holiday Type"].value_counts()
# Out:
# Holiday Type
# weekend                               45
# ashura                                 4
# eid milad un-nabi                      3
# eid-ul-fitar                           3
# labour day                             3
# ashura holiday                         2
# christmas/birthday of quaid-e-azam     2
# eid holidays                           2
# eid-ul-azha                            2
# iqbal day                              2
# pakistan day                           2
# defence day                            1
# general elections                      1
# Name: count, dtype: int64

# %% [markdown]
# # City column

# %%
# code
df["City"]=df["City"].str.lower().str.strip()
df["City"]=df["City"].replace({
    "tangi, charsaddadistrict":"charsadda",
    "shabqadar-charsadda":"charsadda",
    "ghallanai, mohmand agency":"mohmand agency",
    "mosal kor, mohmand agency":"mohmand agency",
    "south waziristan":"waziristan",
    "north waziristan":"waziristan",
    "upper dir":"dir",
    "lower dir":"dir",
})
df['City']=df['City'].astype("category")

# %%
# test
df["City"].value_counts()
# Out:
# City
# peshawar          75
# quetta            38
# waziristan        35
# swat              30
# karachi           29
# lahore            25
# bannu             24
# islamabad         20
# rawalpindi        19
# d.g khan          17
# hangu             17
# khyber agency     15
# bajaur agency     13
# kohat             12
# charsadda         11
# mohmand agency    11
# mardan             9
# tank               8
# dara adam khel     6
# dir                6
# kuram agency       6
# lakki marwat       5
# nowshehra          5
# buner              4
# attock             4
# muzaffarabad       3
# sargodha           3
# malakand           3
# shikarpur          3
# swabi              3
# poonch             2
# shangla            2
# orakzai agency     2
# zhob               2
# multan             2
# chakwal            2
# chaman             2
# gujrat             2
# lasbela            2
# sukkur             1
# bhakkar            1
# wagah              1
# totalai            1
# tirah valley       1
# taunsa             1
# taftan             1
# fateh jang         1
# sudhanoti          1
# sialkot            1
# haripur            1
# sehwan town        1
# hayatabad          1
# jacobabad          1
# karak              1
# khanewal           1
# pishin             1
# khuzdar            1
# mansehra           1
# Name: count, dtype: int64

# %% [markdown]
# # Longitude

# %%
# code
df["Longitude"]=df["Longitude"].astype("float")

# %%
# test
df["Longitude"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Provinces

# %%
# code
df["Province"]=df["Province"].str.lower()
df["Province"]=df["Province"].astype("category")

# %%
# test
df["Province"].value_counts()
# Out:
# Province
# kpk            251
# fata            73
# punjab          64
# balochistan     47
# sindh           35
# capital         20
# ajk              6
# Name: count, dtype: int64

# %% [markdown]
# # Location Category

# %%
# code
df["Location Category"]=df["Location Category"].str.lower().replace({
    "mobile":"attack on Convoy",
    "commercial_residence":"Markets",  
})
df["Location Category"]=df["Location Category"].astype("category")

# %%
# test
df["Location Category"].value_counts()
# Out:
# Location Category
# police_rangers      92
# attack on Convoy    70
# military            70
# religious           57
# market              40
# parks_grounds       32
# residence           27
# government          21
# hotel               10
# office building      9
# foreign              8
# educational          6
# transport            5
# hospital             5
# bank                 4
# Markets              2
# airport              1
# highway              1
# Name: count, dtype: int64

# %% [markdown]
# # Time

# %%
# code
def clean_time(time):
    clean=None
    if not pd.isna(time):
        clean=",".join(re.findall(r"\d{1,2}[:.]\d{1,2}[:.]*\d*\s*[amp]*",time,flags=re.I))
    if clean:
        return clean
    return time
    

df["Time"]=df["Time"].apply(clean_time)

# %%
# test
df["Time"]
# Out:
# S#
# 1              NaN
# 2              NaN
# 3          7:45 AM
# 4      11:10:00 AM
# 5              NaN
#           ...
# 492            NaN
# 493        8:00 AM
# 494        7:00 AM
# 495        7:00 AM
# 496        7:00 AM
# Name: Time, Length: 496, dtype: object

# %% [markdown]
# # Location Sensitivity

# %%
# code
df["Location Sensitivity"]=df["Location Sensitivity"].str.lower()
df["Location Sensitivity"]=df["Location Sensitivity"].astype("category")

# %%
# test
df["Location Sensitivity"].value_counts()
# Out:
# Location Sensitivity
# high      264
# low       121
# medium     75
# Name: count, dtype: int64

# %% [markdown]
# # Open/Closed Space

# %%
# code
df["Open/Closed Space"]=df["Open/Closed Space"].str.lower()
df["Open/Closed Space"]=df["Open/Closed Space"].astype("category")

# %%
# test
df["Open/Closed Space"].value_counts()
# Out:
# Open/Closed Space
# open           333
# closed         127
# open/closed      1
# Name: count, dtype: int64

# %% [markdown]
# # Target Type

# %%
df["Target Type"]=df["Target Type"].str.strip().str.lower()
df["Target Type"]=df["Target Type"].replace({
   "shia sect":"religious" ,
    "frontier corps":"military",
    "civilian judges":"judges_lawyers",
    "advocates_lawyers":"judges_lawyers",
    "children_women":"civilian",
    "army":"military"
})
df["Target Type"]=df["Target Type"].astype("category")

# %%
# test
df["Target Type"].value_counts()
# Out:
# Target Type
# military               119
# police_rangers         119
# civilian                86
# government official     52
# religious               45
# anti_militants          26
# foreigner               17
# judges_lawyers           3
# media                    2
# unknown                  1
# Name: count, dtype: int64

# %% [markdown]
# # Targeted Sect if any

# %%
# code
df["Targeted Sect if any"]=df["Targeted Sect if any"].str.lower()
df["Targeted Sect if any"]=df["Targeted Sect if any"].astype("category")

# %%
# test
df["Targeted Sect if any"].value_counts()
# Out:
# Targeted Sect if any
# shiite          47
# sunni           38
# christian        9
# ahmedi           1
# jews             1
# shiite_sunni     1
# Name: count, dtype: int64

# %% [markdown]
# # Killed Min  Killed Max  Injured Min  Injured Min  No. of Suicide Blasts

# %%
# code
df["Killed Min"]=df["Killed Min"].astype("Int64")
df["Killed Max"]=df["Killed Max"].astype("Int64")
df["Injured Min"]=df["Injured Min"].astype("Int64")
df["Injured Max"]=pd.to_numeric(df["Injured Max"],errors="coerce")
df["Injured Max"]=df["Injured Max"].astype("Int64")
df["No. of Suicide Blasts"]=df["No. of Suicide Blasts"].astype("Int64")

# %%
# test
df[["Killed Min","Killed Max","Injured Min","Injured Max","No. of Suicide Blasts"]]
# Out:
#      Killed Min  Killed Max  Injured Min  Injured Max  No. of Suicide Blasts
# S#
# 1            14          15         <NA>           60                      2
# 2          <NA>           3         <NA>            3                      1
# 3            13          15           20           40                      1
# 4          <NA>          12         <NA>           51                      1
# 5            44          47         <NA>           65                      1
# ..          ...         ...          ...          ...                    ...
# 492          21          22           25         <NA>                      1
# 493           7           7           22           22                      1
# 494           2           2            8            8                      1
# 495           1           3            6            8                      1
# 496           4           4           16           22                      1
#
# [496 rows x 5 columns]

# %% [markdown]
# # avg kill and avg injured

# %%
    
df["avg total killed"]=df[["Killed Max","Killed Min"]].mean(axis=1,skipna=True)
df["avg total injured"]=df[["Injured Max","Injured Min"]].mean(axis=1,skipna=True)

# %% [markdown]
# # Explosive Weight (max)

# %%
# code
def int_conversion(values):
    if not pd.isna(values):
        if "-" in values:
            d1,d2=values.split("-")
            return (float(d1)+float(d2))/2
        else:
            return float(values)
    return 0
df["Explosive Weight (max)"]=df["Explosive Weight (max)"].str.replace(r"[a-zA-Z]","",regex=True).str.strip().str.replace(r"\s+","-",regex=True).apply(int_conversion)
df.rename(columns={"Explosive Weight (max)":"Explosive Weight (max)(kg)"},inplace=True)

# %%
# test
df["Explosive Weight (max)(kg)"].unique()
# Out:
# array([   0. ,    2.5,   30. ,    2. ,   12.5,    5. ,   10. ,    5.5,
#          15. ,    3. ,    6.5,    4.5,   50. ,  100. ,  150. , 1000. ,
#           8. ,   60. ,   40. ,    7.5,   85. ,  125. ,  160. ,  500. ,
#          24. ,   20. ,   12. ,  180. ,   70. ,   16. ,    7. ,  400. ,
#         200. ,   55. ,  250. ,  600. ,   14. ,  300. ,    6. , 1200. ,
#           9. ,   18. ,  450. ,  105. ,  700. ,   22.5,   27.5,   45. ,
#          13. ,   75. ,   25. ])

# %% [markdown]
# # Hospital Names

# %%
# code

hos_name=df["Hospital Names"].str.strip().str.lower().str.replace(r"[\d\n.]","",regex=True).str.split(r"/|-|and",regex=True)
df["Hospital Names"]=df["Hospital Names"].str.strip().str.lower().str.replace(r"[\d\n.]","",regex=True).str.split(r"/|-|and",regex=True)

# %%
# test
df["Hospital Names"]
# Out:
# S#
# 1                                                    NaN
# 2                                                    NaN
# 3      [jinnah postgraduate medical center  civil hos...
# 4                                                    NaN
# 5      [cmh quettacivil hospital  bol,  medical complex]
#                              ...
# 492    [larkana hospital, g, awah district headquarte...
# 493                                                  NaN
# 494    [combined military hospital (cmh), (quetta), c...
# 495                [hayatabad medical complex(peshawar)]
# 496                             [civil hospital(quetta)]
# Name: Hospital Names, Length: 496, dtype: object

# %%
df
# Out:
#           Date  Year                   Islamic Date Blast Day Type  \
# S#
# 1   1995-11-19  1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 2   2000-11-06  2000           10 SHa`baan 1421 A.H    Working Day
# 3   2002-05-08  2002              25 safar 1423 A.H    Working Day
# 4   2002-06-14  2002     3 Raby` al-THaany 1423 A.H    Working Day
# 5   2003-07-04  2003     4 Jumaada al-awal 1424 A.H    Working Day
# ..         ...   ...                            ...            ...
# 492 2017-10-05  2017           13 MuHarram 1439 A.H    Working Day
# 493 2017-10-19  2017           27 MuHarram 1439 A.H    Working Day
# 494 2017-11-09  2017              19 Safar 1439 A.H    Working Day
# 495 2017-11-24  2017       5 Rabi Al-Awwal 1439 A.H    Working Day
# 496 2017-11-25  2017       6 Rabi Al-Awwal 1439 A.H    Working Day
#
#     Holiday Type         Time       City   Latitude  Longitude     Province  \
# S#
# 1        weekend          NaN  islamabad  33.718000  73.071800      capital
# 2            NaN          NaN    karachi  24.991800  66.991100        sindh
# 3            NaN      7:45 AM    karachi  24.991800  66.991100        sindh
# 4            NaN  11:10:00 AM    karachi  24.991800  66.991100        sindh
# 5            NaN          NaN     quetta  30.209500  67.018200  balochistan
# ..           ...          ...        ...        ...        ...          ...
# 492          NaN          NaN     quetta  28.571051  67.496895  balochistan
# 493          NaN      8:00 AM     quetta        NaN        NaN  balochistan
# 494          NaN      7:00 AM     quetta  30.221057  67.002524  balochistan
# 495          NaN      7:00 AM   peshawar  33.970623  71.438620          kpk
# 496          NaN      7:00 AM     quetta  30.139626  66.981476  balochistan
#
#                                               Location Location Category  \
# S#
# 1                                     Egyptian Embassy           foreign
# 2                                office of Nawa-e-Waqt   office building
# 3    Pakistan Navy bus Parked outside Five Star She...             hotel
# 4                       US Consulate Civil Lines Area            foreign
# 5                       Imambargah MeCongy Road Quetta         religious
# ..                                                 ...               ...
# 492             Fateh Pur Shrine in Jhal Magsi village         religious
# 493                                   Sariab Mill area           highway
# 494     Quetta's Chaman Housing Scheme on airport road    police_rangers
# 495            Near Zarghuni Masjid, Phase-2 Hayatabad    police_rangers
# 496                     Sariab Road, near Bus terminal          military
#
#     Location Sensitivity Open/Closed Space  \
# S#
# 1                   high            closed
# 2                    low            closed
# 3                 medium            closed
# 4                   high            closed
# 5                 medium            closed
# ..                   ...               ...
# 492                 high       open/closed
# 493                  low              open
# 494                  low              open
# 495                  low              open
# 496               medium              open
#
#                                Influencing Event/Event     Target Type  \
# S#
# 1                                                  NaN       foreigner
# 2                                                  NaN           media
# 3                                                  NaN       foreigner
# 4                                                  NaN       foreigner
# 5                                 during Friday prayer       religious
# ..                                                 ...             ...
# 492                          at the entrance of shrine        civilian
# 493  explosives-laden vehicle rammed into a securit...  police_rangers
# 494                         AIG Hamid Shakil’s vehicle  police_rangers
# 495     a Police & Rangers vehicle of AIG Asharf Noor   police_rangers
# 496  transport for a colonel in Pakistan's armed fo...        military
#
#     Targeted Sect if any  Killed Min  Killed Max  Injured Min  Injured Max  \
# S#
# 1                    NaN          14          15         <NA>           60
# 2                    NaN        <NA>           3         <NA>            3
# 3              christian          13          15           20           40
# 4              christian        <NA>          12         <NA>           51
# 5                 shiite          44          47         <NA>           65
# ..                   ...         ...         ...          ...          ...
# 492                  NaN          21          22           25         <NA>
# 493                  NaN           7           7           22           22
# 494                  NaN           2           2            8            8
# 495                  NaN           1           3            6            8
# 496                  NaN           4           4           16           22
#
#      No. of Suicide Blasts  Explosive Weight (max)(kg)  \
# S#
# 1                        2                         0.0
# 2                        1                         0.0
# 3                        1                         2.5
# 4                        1                         0.0
# 5                        1                         0.0
# ..                     ...                         ...
# 492                      1                         0.0
# 493                      1                         0.0
# 494                      1                        15.0
# 495                      1                        20.0
# 496                      1                        10.0
#
#                                         Hospital Names  Temperature(C)  \
# S#
# 1                                                  NaN          15.835
# 2                                                  NaN          23.770
# 3    [jinnah postgraduate medical center  civil hos...          31.460
# 4                                                  NaN          31.430
# 5    [cmh quettacivil hospital  bol,  medical complex]          33.120
# ..                                                 ...             ...
# 492  [larkana hospital, g, awah district headquarte...          27.800
# 493                                                NaN          26.000
# 494  [combined military hospital (cmh), (quetta), c...          25.000
# 495              [hayatabad medical complex(peshawar)]          22.000
# 496                           [civil hospital(quetta)]          29.000
#
#      Temperature(F) month_name   day_name  avg total killed  avg total injured
# S#
# 1            60.503   November     Sunday              14.5               60.0
# 2            74.786   November     Monday               3.0                3.0
# 3            88.628        May  Wednesday              14.0               30.0
# 4            88.574       June     Friday              12.0               51.0
# 5            91.616       July     Friday              45.5               65.0
# ..              ...        ...        ...               ...                ...
# 492          81.000    October   Thursday              21.5               25.0
# 493          79.000    October   Thursday               7.0               22.0
# 494          77.000   November   Thursday               2.0                8.0
# 495          72.000   November     Friday               2.0                7.0
# 496          84.000   November   Saturday               4.0               19.0
#
# [496 rows x 30 columns]

# %%
df.to_pickle("cleaned_explosions.pkl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 496 entries, 1 to 496
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        496 non-null    datetime64[ns]
#  1   Year                        496 non-null    int64
#  2   Islamic Date                342 non-null    object
#  3   Blast Day Type              486 non-null    category
#  4   Holiday Type                72 non-null     category
#  5   Time                        285 non-null    object
#  6   City                        496 non-null    category
#  7   Latitude                    493 non-null    float64
#  8   Longitude                   493 non-null    float64
#  9   Province                    496 non-null    category
#  10  Location                    493 non-null    object
#  11  Location Category           460 non-null    category
#  12  Location Sensitivity        460 non-null    category
#  13  Open/Closed Space           461 non-null    category
#  14  Influencing Event/Event     191 non-null    object
#  15  Target Type                 470 non-null    category
#  16  Targeted Sect if any        97 non-null     category
#  17  Killed Min                  350 non-null    Int64
#  18  Killed Max                  480 non-null    Int64
#  19  Injured Min                 365 non-null    Int64
#  20  Injured Max                 461 non-null    Int64
#  21  No. of Suicide Blasts       414 non-null    Int64
#  22  Explosive Weight (max)(kg)  496 non-null    float64
#  23  Hospital Names              297 non-null    object
#  24  Temperature(C)              491 non-null    float64
#  25  Temperature(F)              489 non-null    float64
#  26  month_name                  496 non-null    category
#  27  day_name                    496 non-null    category
#  28  avg total killed            484 non-null    Float64
#  29  avg total injured           470 non-null    Float64
# dtypes: Float64(2), Int64(5), category(11), datetime64[ns](1), float64(5), int64(1), object(5)
# memory usage: 92.1+ KB
